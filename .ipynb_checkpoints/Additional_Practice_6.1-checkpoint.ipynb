# %% [markdown]
# #### Get Data from the following link: http://files.grouplens.org/datasets/movielens/ml-20m.zip
# #### We will be using the following files for this exercise:
#     ratings.csv : userId,movieId,rating, timestamp
#     tags.csv : userId,movieId, tag, timestamp
#     movies.csv : movieId, title, genres
# #### 1. Read the dataset using pandas.

# %%
import pandas as pd
import os

path="C:\\Users\\manoj\\Documents\\Acadgild DSB\\S6 - Pandas 2\\Assignments\\Additional_Practice_6.1"
os.chdir(path)

ratings=pd.read_csv("ratings.csv")
tags=pd.read_csv("tags.csv")
movies=pd.read_csv("movies.csv")

# %% [markdown]
# #### 2. Extract the first row from tags and print its type.

# %%
tagsFirstRow=tags.iloc[0]
print(type(tagsFirstRow))
# Out:
# <class 'pandas.core.series.Series'>

# %% [markdown]
# #### 3. Extract row 0, 11, 2000 from tags DataFrame.

# %%
tags.iloc[[0,11,2000]]
# Out:
#       userId  movieId                tag   timestamp
# 0         18     4141        Mark Waters  1240597180
# 11        65     1783      noir thriller  1368149983
# 2000     910    68554  conspiracy theory  1368043943

# %% [markdown]
# #### 4. Print index, columns of the DataFrame.

# %%
print(ratings.index.values)
print(ratings.columns.values)
print(tags.index.values)
print(tags.columns.values)
print(movies.index.values)
print(movies.columns.values)
# Out:
# [       0        1        2 ... 20000260 20000261 20000262]
# ['userId' 'movieId' 'rating' 'timestamp']
# [     0      1      2 ... 465561 465562 465563]
# ['userId' 'movieId' 'tag' 'timestamp']
# [    0     1     2 ... 27275 27276 27277]
# ['movieId' 'title' 'genres']

# %% [markdown]
# #### 5. Calculate descriptive statistics for the 'ratings' column of the ratings DataFrame. Verify using describe().

# %%
print("count\t"+str(ratings.rating.count()))
print("mean\t"+str(ratings.rating.mean()))
print("std\t"+str(ratings.rating.std()))
print("min\t"+str(ratings.rating.min()))
print("25%\t"+str(ratings.rating.quantile(0.25)))
print("50%\t"+str(ratings.rating.quantile(0.5)))
print("75%\t"+str(ratings.rating.quantile(0.75)))
print("max\t"+str(ratings.rating.max()))
print(ratings.rating.describe())
# Out:
# count	20000263
# mean	3.5255285642993797
# std	1.051988919275684
# min	0.5
# 25%	3.0
# 50%	3.5
# 75%	4.0
# max	5.0
# count    2.000026e+07
# mean     3.525529e+00
# std      1.051989e+00
# min      5.000000e-01
# 25%      3.000000e+00
# 50%      3.500000e+00
# 75%      4.000000e+00
# max      5.000000e+00
# Name: rating, dtype: float64

# %% [markdown]
# #### 6. Filter out ratings with rating > 4

# %%
ratings[ratings.rating>4].head()
# Out:
#      userId  movieId  rating   timestamp
# 30        1     1196     4.5  1112484742
# 31        1     1198     4.5  1112484624
# 131       1     4993     5.0  1112484682
# 142       1     5952     5.0  1112484619
# 158       1     7153     5.0  1112484633

# %% [markdown]
# #### 7. Find how many null values, missing values are present. Deal with them. Print out how many rows have been modified.

# %%
    #Checking each dataframe
print("ratings has null:- "+str(ratings.isnull().any().any()))
print("tags has null:- " +str(tags.isnull().any().any()))
print("movies has null:- " +str(movies.isnull().any().any()))
    #Removing null rows
oldCount=tags.movieId.count()
noOfNullRows = tags[tags.tag.isnull()].movieId.count()
tags.dropna(inplace=True)
newCount=tags.movieId.count()
    #Check if the correct count has been removed
print("Old Count:- " + str(oldCount))
print("New Count:- " + str(newCount))
print("Null Count:- " + str(noOfNullRows))
print("Number of Null count matches with old count - new count? :- " + str(noOfNullRows ==(oldCount-newCount)))
# Out:
# ratings has null:- False
# tags has null:- True
# movies has null:- False
# Old Count:- 465564
# New Count:- 465548
# Null Count:- 16
# Number of Null count matches with old count - new count? :- True

# %% [markdown]
# #### 8. Filter out movies from the movies DataFrame that are of type 'Animation'.

# %%
movies[movies['genres']=="Animation"].head()
# Out:
#       movieId                                    title     genres
# 2503     2588                         Cloudland (1998)  Animation
# 4906     5002                     Fritz the Cat (1972)  Animation
# 4907     5003  Nine Lives of Fritz the Cat, The (1974)  Animation
# 9455    27738          Cathedral, The (Katedra) (2002)  Animation
# 9989    32840                           Vincent (1982)  Animation

# %% [markdown]
# #### 9. Find the average rating of movies.

# %%
import numpy as np
print(ratings.groupby("movieId")["rating"].agg(np.mean))
# Out:
# movieId
# 1         3.921240
# 2         3.211977
# 3         3.151040
# 4         2.861393
# 5         3.064592
# 6         3.834930
# 7         3.366484
# 8         3.142049
# 9         3.004924
# 10        3.430029
# 11        3.667713
# 12        2.619766
# 13        3.272416
# 14        3.432082
# 15        2.721993
# 16        3.787455
# 17        3.968573
# 18        3.373631
# 19        2.607412
# 20        2.880754
# 21        3.581689
# 22        3.319400
# 23        3.148235
# 24        3.199849
# 25        3.689510
# 26        3.628857
# 27        3.413520
# 28        4.057546
# 29        3.952230
# 30        3.633880
#             ...
# 131146    4.000000
# 131148    4.000000
# 131150    4.000000
# 131152    0.500000
# 131154    3.500000
# 131156    4.000000
# 131158    4.000000
# 131160    4.000000
# 131162    2.000000
# 131164    4.000000
# 131166    4.000000
# 131168    3.500000
# 131170    3.500000
# 131172    1.000000
# 131174    3.500000
# 131176    4.500000
# 131180    2.500000
# 131231    3.500000
# 131237    3.000000
# 131239    4.000000
# 131241    4.000000
# 131243    4.000000
# 131248    4.000000
# 131250    4.000000
# 131252    4.000000
# 131254    4.000000
# 131256    4.000000
# 131258    2.500000
# 131260    3.000000
# 131262    4.000000
# Name: rating, Length: 26744, dtype: float64

# %% [markdown]
# #### 10. Perform an inner join of movies and tags based on movieId.

# %%
pd.merge(movies,tags,on="movieId").head()
# Out:
#    movieId             title                                       genres  \
# 0        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 1        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 2        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 3        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 4        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
#
#    userId                                     tag   timestamp
# 0    1644                                 Watched  1417736680
# 1    1741                      computer animation  1183903155
# 2    1741                 Disney animated feature  1183933307
# 3    1741                         Pixar animation  1183934770
# 4    1741  T̩a Leoni does not star in this movie  1245093573

# %% [markdown]
# #### 11. Print out the 5 movies that belong to the Comedy genre and have rating greater than 4.

# %%
movies_ratings=pd.merge(movies,ratings,on="movieId")
comedy_4=movies_ratings[(movies_ratings["genres"].str.contains("Comedy")) & (movies_ratings["rating"]>4)].groupby("movieId")
comedy_4.head()
# Out:
#           movieId                                              title  \
# 1               1                                   Toy Story (1995)
# 4               1                                   Toy Story (1995)
# 7               1                                   Toy Story (1995)
# 9               1                                   Toy Story (1995)
# 14              1                                   Toy Story (1995)
# 71941           3                            Grumpier Old Men (1995)
# 71952           3                            Grumpier Old Men (1995)
# 71959           3                            Grumpier Old Men (1995)
# 71976           3                            Grumpier Old Men (1995)
# 71990           3                            Grumpier Old Men (1995)
# 84683           4                           Waiting to Exhale (1995)
# 84684           4                           Waiting to Exhale (1995)
# 84699           4                           Waiting to Exhale (1995)
# 84703           4                           Waiting to Exhale (1995)
# 84707           4                           Waiting to Exhale (1995)
# 87435           5                 Father of the Bride Part II (1995)
# 87437           5                 Father of the Bride Part II (1995)
# 87455           5                 Father of the Bride Part II (1995)
# 87460           5                 Father of the Bride Part II (1995)
# 87462           5                 Father of the Bride Part II (1995)
# 123489          7                                     Sabrina (1995)
# 123493          7                                     Sabrina (1995)
# 123496          7                                     Sabrina (1995)
# 123501          7                                     Sabrina (1995)
# 123511          7                                     Sabrina (1995)
# 170830         11                     American President, The (1995)
# 170840         11                     American President, The (1995)
# 170842         11                     American President, The (1995)
# 170853         11                     American President, The (1995)
# 170855         11                     American President, The (1995)
# ...           ...                                                ...
# 19999624   129348                    A Short History of Decay (2014)
# 19999629   129354                                       Focus (2015)
# 19999642   129354                                       Focus (2015)
# 19999648   129354                                       Focus (2015)
# 19999650   129354                                       Focus (2015)
# 19999653   129354                                       Focus (2015)
# 19999665   129370   SpongeBob Movie: Sponge Out of Water, The (2015)
# 19999683   129401  Kevin Smith: Sold Out - A Threevening with Kev...
# 19999704   129428       The Second Best Exotic Marigold Hotel (2015)
# 19999708   129428       The Second Best Exotic Marigold Hotel (2015)
# 19999714   129428       The Second Best Exotic Marigold Hotel (2015)
# 19999715   129428       The Second Best Exotic Marigold Hotel (2015)
# 19999719   129428       The Second Best Exotic Marigold Hotel (2015)
# 19999731   129451                                   Ingenious (2009)
# 19999744   129514             George Carlin: It's Bad for Ya! (2008)
# 19999745   129514             George Carlin: It's Bad for Ya! (2008)
# 19999746   129514             George Carlin: It's Bad for Ya! (2008)
# 19999747   129514             George Carlin: It's Bad for Ya! (2008)
# 19999750   129516                                      Poison (1951)
# 19999751   129518                                  Forgive Me (2006)
# 19999753   129520                                        Papa (2005)
# 19999756   129526                           The Color of Milk (2004)
# 19999800   129719                                 That's Life (1998)
# 19999816   129773                                    Soulless (2012)
# 19999866   129905                         The Floating Castle (2012)
# 19999995   130347                        Bill Hicks: Sane Man (1989)
# 20000157   130970         George Carlin: Life Is Worth Losing (2005)
# 20000158   130970         George Carlin: Life Is Worth Losing (2005)
# 20000162   130978                            Love and Pigeons (1985)
# 20000182   131027                      But Forever in My Mind (1999)
#
#                                                genres  userId  rating  \
# 1         Adventure|Animation|Children|Comedy|Fantasy       6     5.0
# 4         Adventure|Animation|Children|Comedy|Fantasy      11     4.5
# 7         Adventure|Animation|Children|Comedy|Fantasy      14     4.5
# 9         Adventure|Animation|Children|Comedy|Fantasy      19     5.0
# 14        Adventure|Animation|Children|Comedy|Fantasy      34     5.0
# 71941                                  Comedy|Romance       8     5.0
# 71952                                  Comedy|Romance     117     5.0
# 71959                                  Comedy|Romance     251     5.0
# 71976                                  Comedy|Romance     465     5.0
# 71990                                  Comedy|Romance     593     5.0
# 84683                            Comedy|Drama|Romance     518     5.0
# 84684                            Comedy|Drama|Romance     601     5.0
# 84699                            Comedy|Drama|Romance    1638     5.0
# 84703                            Comedy|Drama|Romance    1931     5.0
# 84707                            Comedy|Drama|Romance    2174     5.0
# 87435                                          Comedy     117     5.0
# 87437                                          Comedy     127     5.0
# 87455                                          Comedy     350     5.0
# 87460                                          Comedy     390     5.0
# 87462                                          Comedy     401     5.0
# 123489                                 Comedy|Romance       6     5.0
# 123493                                 Comedy|Romance      19     5.0
# 123496                                 Comedy|Romance      38     5.0
# 123501                                 Comedy|Romance     113     5.0
# 123511                                 Comedy|Romance     251     5.0
# 170830                           Comedy|Drama|Romance       5     5.0
# 170840                           Comedy|Drama|Romance      54     5.0
# 170842                           Comedy|Drama|Romance      58     4.5
# 170853                           Comedy|Drama|Romance     156     5.0
# 170855                           Comedy|Drama|Romance     160     5.0
# ...                                               ...     ...     ...
# 19999624                                       Comedy   68026     4.5
# 19999629                   Comedy|Crime|Drama|Romance   21210     4.5
# 19999642                   Comedy|Crime|Drama|Romance   51995     5.0
# 19999648                   Comedy|Crime|Drama|Romance   81396     4.5
# 19999650                   Comedy|Crime|Drama|Romance   98886     5.0
# 19999653                   Comedy|Crime|Drama|Romance  130746     5.0
# 19999665          Adventure|Animation|Children|Comedy   79570     4.5
# 19999683                           Comedy|Documentary   74142     5.0
# 19999704                                 Comedy|Drama   17308     5.0
# 19999708                                 Comedy|Drama   36725     4.5
# 19999714                                 Comedy|Drama   94583     5.0
# 19999715                                 Comedy|Drama   95692     5.0
# 19999719                                 Comedy|Drama  137055     5.0
# 19999731                         Comedy|Drama|Romance   51558     4.5
# 19999744                                       Comedy   59417     5.0
# 19999745                                       Comedy   61923     4.5
# 19999746                                       Comedy   69470     4.5
# 19999747                                       Comedy   85554     5.0
# 19999750                                       Comedy   52697     5.0
# 19999751                                       Comedy   52697     4.5
# 19999753                                 Comedy|Drama  115147     4.5
# 19999756                                 Comedy|Drama   52697     5.0
# 19999800                                       Comedy   13965     4.5
# 19999816                                 Comedy|Drama   98886     4.5
# 19999866                                 Comedy|Drama  134701     5.0
# 19999995                                       Comedy  122319     5.0
# 20000157                                       Comedy   69470     4.5
# 20000158                                       Comedy   86211     5.0
# 20000162                               Comedy|Romance   26497     5.0
# 20000182                                 Comedy|Drama   67380     4.5
#
#            timestamp
# 1          858275452
# 4         1230858821
# 7         1225311239
# 9          855176628
# 14         846509445
# 71941      833981733
# 71952      861553146
# 71959      965281199
# 71976      845587969
# 71990      861600366
# 84683      839943473
# 84684      848681183
# 84699      836265704
# 84703      848772700
# 84707      851331452
# 87435      861553146
# 87437      847127740
# 87455     1360209812
# 87460      836139583
# 87462      847049988
# 123489     858275558
# 123493     855176684
# 123496     835885746
# 123501     858515847
# 123511     965280700
# 170830     851527751
# 170840     974840528
# 170842    1144058674
# 170853    1039204154
# 170855     833408806
# ...              ...
# 19999624  1426052215
# 19999629  1426671332
# 19999642  1425664317
# 19999648  1425894209
# 19999650  1425999861
# 19999653  1427667496
# 19999665  1427651953
# 19999683  1425516517
# 19999704  1426180427
# 19999708  1425889164
# 19999714  1425832655
# 19999715  1426912943
# 19999719  1426126053
# 19999731  1425259558
# 19999744  1425800432
# 19999745  1425682929
# 19999746  1425418010
# 19999747  1426064725
# 19999750  1425418445
# 19999751  1425418697
# 19999753  1425419345
# 19999756  1425421180
# 19999800  1425815628
# 19999816  1425999894
# 19999866  1426268235
# 19999995  1426542491
# 20000157  1427401153
# 20000158  1427490566
# 20000162  1427532559
# 20000182  1427612224
#
# [22300 rows x 6 columns]

# %% [markdown]
# #### 12. Split 'genres' into multiple columns.

# %%
m=pd.concat([movies.drop(["genres"],axis=1),pd.DataFrame(movies["genres"].str.split("|").tolist()).apply(pd.Series).rename(columns={0:"genre_0",1:"genre_1",2:"genre_2",3:"genre_3",4:"genre_4",5:"genre_5",6:"genre_6",7:"genre_7",8:"genre_8",9:"genre_9"})],axis=1)
m.head()
# Out:
#    movieId                               title    genre_0    genre_1  \
# 0        1                    Toy Story (1995)  Adventure  Animation
# 1        2                      Jumanji (1995)  Adventure   Children
# 2        3             Grumpier Old Men (1995)     Comedy    Romance
# 3        4            Waiting to Exhale (1995)     Comedy      Drama
# 4        5  Father of the Bride Part II (1995)     Comedy       None
#
#     genre_2 genre_3  genre_4 genre_5 genre_6 genre_7 genre_8 genre_9
# 0  Children  Comedy  Fantasy    None    None    None    None    None
# 1   Fantasy    None     None    None    None    None    None    None
# 2      None    None     None    None    None    None    None    None
# 3   Romance    None     None    None    None    None    None    None
# 4      None    None     None    None    None    None    None    None

# %% [markdown]
# #### 13. Extract year from title e.g. (1995).

# %%
movies['title'].str.extract('(\(\d{4}\))',expand=True).head()
# Out:
#         0
# 0  (1995)
# 1  (1995)
# 2  (1995)
# 3  (1995)
# 4  (1995)

# %%
movies['title'].str.extract('(\d{4})',expand=True).head()
# Out:
#       0
# 0  1995
# 1  1995
# 2  1995
# 3  1995
# 4  1995

# %% [markdown]
# #### 14. Select rows based on timestamps later than 2015-02-01.

# %%
t=pd.concat([tags.drop(["timestamp"],axis=1),pd.to_datetime(tags['timestamp'], unit='s')],axis=1)
t[t['timestamp']>'2015-02-01'].head()
# Out:
#      userId  movieId      tag           timestamp
# 301     318      260    1970s 2015-02-20 22:42:49
# 302     318      260  fantasy 2015-02-20 22:42:49
# 303     318      260   sci-fi 2015-02-20 22:42:49
# 304     318   115149   Action 2015-02-21 15:58:30
# 305     318   115149  Revenge 2015-02-21 15:58:03

# %% [markdown]
# #### 15. Sort the tags DataFrame based on timestamp.

# %%
tags.sort_values("timestamp").head()
# Out:
#         userId  movieId              tag   timestamp
# 333932  100371     2788     monty python  1135429210
# 333927  100371     1732    coen brothers  1135429236
# 333924  100371     1206  stanley kubrick  1135429248
# 333923  100371     1193   jack nicholson  1135429371
# 333939  100371     5004    peter sellers  1135429399
